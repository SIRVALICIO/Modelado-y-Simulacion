# %% [markdown]
# <a href="https://colab.research.google.com/github/valquero779/Modelado-y-Simulacion/blob/main/NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Integrantes Henry Nuñez Suarez, Camilo Serrano


import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import numpy as np


datosDiabetes = pd.read_excel('diabetes (1).xlsx')
print(datosDiabetes)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#Correlacion de los embarazos y la diabetes
plt.scatter(datosDiabetes["Pregnancies"],datosDiabetes["Outcome"])

# %%
#Correlacion de la presion saguinea y la diabetes
plt.scatter(datosDiabetes["BloodPressure"],datosDiabetes["Outcome"])

# %%
#Correlacion de la glucosa y la diabetes
plt.scatter(datosDiabetes["Glucose"],datosDiabetes["Outcome"])

# %%
#Correlacion del grosor de la piel y la diabetes
plt.scatter(datosDiabetes["SkinThickness"],datosDiabetes["Outcome"])

# %%
#Corelacion de la insulina y la diabetes
plt.scatter(datosDiabetes["Insulin"],datosDiabetes["Outcome"])

# %%
#Corelacion del BMI y la diabetes
plt.scatter(datosDiabetes["BMI"],datosDiabetes["Outcome"])

# %%
#Correlacion de x y la diabetes
plt.scatter(datosDiabetes["DiabetesPedigreeFunction"],datosDiabetes["Outcome"])

# %%
#Correlacion de la edad y la diabetes
plt.scatter(datosDiabetes["Age"],datosDiabetes["Outcome"])

# %%
matrizDeCorrelacion=datosDiabetes.corr()
print(matrizDeCorrelacion)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
datosTeoricos= datosDiabetes[[ 'Glucose','BloodPressure'
,'Insulin','BMI','DiabetesPedigreeFunction',"Outcome"]]




plt.scatter(datosTeoricos["Glucose"],datosTeoricos["Insulin"],datosTeoricos["DiabetesPedigreeFunction"],datosTeoricos["Outcome"] )

# %%
plt.scatter(datosTeoricos["Glucose"],datosTeoricos["Insulin"],datosTeoricos["BMI"],datosTeoricos["Outcome"] )

# %%
plt.scatter(datosTeoricos["Glucose"],datosTeoricos["Insulin"],datosTeoricos["BloodPressure"],datosTeoricos["Outcome"] )

# %%
x=datosTeoricos= datosDiabetes[[ 'Glucose',
'Insulin','BMI','DiabetesPedigreeFunction']]
y=datosTeoricos= datosDiabetes[[ 'Outcome']]

# %%
#print(len(X),type(X))
#print(X[0])
#print(len(X[0]))
#print(y)

clf = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(10,8,20))

# %%
clf.fit(x,y)
c=clf.n_layers_
d=clf.coefs_
#print(c)
#print(d)
contandor=0
for i in d:
  print('coeficientes de la capa numero',contandor)
  print(len(i))
  print(i)
  contandor=contandor+1
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# coeficientes de la capa numero 0
# 4
# [[-0.57550269 -0.68351922  0.21739422 -0.69179815 -0.46636334  0.01536691
#    0.08280895 -0.45998388 -0.13201127 -0.81282474]
#  [-0.18596908  0.55874563  0.53026437  0.20984337  0.38767828 -1.13094495
#   -1.16128731  0.25752697  0.19535176  0.38751207]
#  [-0.60605766  0.88013777  0.37250605 -0.23774725  0.03268177  0.11540949
#    0.06609669 -0.08603055 -0.06009982 -0.2261361 ]
#  [ 0.49724042 -0.36800803  0.56629947  0.42735999  0.41317915  0.64225032
#    0.18605894  0.34568724 -0.20634521  0.16417339]]
# coeficientes de la capa numero 1
# 10
# [[ 0.5127162   0.49440782  0.1494834   0.31645413 -0.33206336 -0.36224415
#   -0.38763132  0.54738483]
# ...

# %%
#X, y = make_classification(n_samples=100, random_state=2)

X_train, X_test, y_train, y_test = train_test_split(x, y, stratify=y,
                                                    train_size=0.7,
                                                    )

clf = MLPClassifier(#random_state=1, 
                    max_iter=100).fit(X_train, y_train)
#paso de 100
clf.score(X_test, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# 0.7229437229437229
